# %%
names=input("enter some names:")
namess=list(names.split("'"))
for name in namess:
    print(name)
# Out:
# enter some names: sinu,anu,manu
# sinu,anu,manu

# %%
num=int(input("enter any range:"))
for i in range(num):
    print(i)
# Out:
# enter any range: 5
# 0
# 1
# 2
# 3
# 4

# %%
# d dict
Rno=input("Enter the roll number for 3 students [using space]:").split()
Rno1=list(map(int,Rno))
names=input("Enter 3 students names [using space]:").split()

students=dict(zip(Rno,names))
print("Students with Roll_numbers:",students)

Rno2=input("Enter the roll number for 2 students:").split()
Rno3=list(map(int,Rno))
names1=input("Enter 2 students names:").split()

students1=dict(zip(Rno3,names1))
print("Students with Roll_numbers:",students1)

students.update(students1)
print("Merged dictionary:",students)
# Out:
# Enter the roll number for 3 students [using space]: 2 4 6
# Enter 3 students names [using space]: sinu manu anu
# Students with Roll_numbers: {'2': 'sinu', '4': 'manu', '6': 'anu'}
# Enter the roll number for 2 students: 8 9
# Enter 2 students names: veenA ADHI
# Students with Roll_numbers: {2: 'veenA', 4: 'ADHI'}
# Merged dictionary: {'2': 'sinu', '4': 'manu', '6': 'anu', 2: 'veenA', 4: 'ADHI'}

# %%
numb=set(map(int,input("enter numbers:").split(",")))
print("set is:",numb)
# Out:
# enter numbers: 2,4,5,6
# set is: {2, 4, 5, 6}

# %%
num1=tuple(map(int,input("enter  numbers:").split(",")))
print("Tuple is:",num1)
# Out:
# enter  numbers: 3,5,2,6
# Tuple is: (3, 5, 2, 6)

# %%
#functiion
num=int(input("Enter a number:"))

def factorial(num):
    return[i for i in range(1,num+1) if num%i==0]

print("The factorial of the number",num, " is:",factorial(num))
# Out:
# Enter a number: 37
# The factorial of the number 37  is: [1, 37]

# %%
# e using function return true if 2 list have atleast one common value
def common_member(list1, list2):
    for item in list1:
        if item in list2:
            return True
    return False

list1 = [4,7,8,2]
list2 = [3,4,2,5]

print(common_member(list1, list2))
# Out:
# True

# %%
# c convert tuple to dict
keys = ("aju", "manu", "vinu")
values = (21, 22, 23)

d = dict(zip(keys, values))

print(d)
# Out:
# {'aju': 21, 'manu': 22, 'vinu': 23}

# %%
#a largets number from list
numbers = [3,7,9,2]

largest = max(numbers)

print("Largest number:", largest)
# Out:
# Largest number: 9

# %%
#b remove duplicates
numbers = [1, 2, 2, 3, 4, 4, 5]

unique = list(set(numbers))

print(unique)
# Out:
# [1, 2, 3, 4, 5]
